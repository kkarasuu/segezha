# %%
import numpy as np
import streamlit as st
import pandas as pd
import plotly.express as px
import plotly.offline as py 
import plotly.graph_objs as go 
from plotly.figure_factory import create_table

# %%
asia_data = pd.read_csv("asia_construction.csv")
asia_data.dropna()
asia_data.head()
# Out:
#    Year construction billion dollars (current prices)  \
# 0  1970                                          27.7
# 1  1971                                          31.5
# 2  1972                                          39.8
# 3  1973                                          53.8
# 4  1974                                          62.9
#
#    construction per capita dollars (current prices)  \
# 0                                              13.2
# 1                                              14.6
# 2                                              18.2
# 3                                              24.0
# 4                                              27.4
#
#    construction billion dollars (constant prices 1970)  \
# 0                                               27.7
# 1                                               29.5
# 2                                               31.7
# 3                                               34.2
# 4                                               33.7
#
#    construction growth % (constant prices 1970)  \
# 0                                           0.0
# 1                                           6.4
# 2                                           7.7
# 3                                           7.7
# 4                                          -1.3
#
#    share of construction in the economy %  Asia's share in the world %
# 0                                     5.5                         12.9
# 1                                     5.7                         13.1
# 2                                     6.0                         14.0
# 3                                     6.1                         15.6
# 4                                     5.9                         16.4

# %%
# Загрузка данных из CSV файла
data = pd.read_csv("asia_construction.csv")

# Создание графика
fig = go.Figure()

# Добавление кривой для construction billion dollars (current prices)
fig.add_trace(go.Scatter(
    x=data['Year'],
    y=data['construction billion dollars (current prices)'],
    mode='lines',
    name='Current Prices',
    line=dict(color='blue')
))

# Добавление кривой для construction billion dollars (constant prices 1970)
fig.add_trace(go.Scatter(
    x=data['Year'],
    y=data['construction billion dollars (constant prices 1970)'],
    mode='lines',
    name='Constant Prices (1970)',
    line=dict(color='red')
))

# Обновление макета графика
fig.update_layout(
    title='Construction Spending in Asia',
    xaxis_title='Year',
    yaxis_title='Billion Dollars',
    legend_title='Legend'
)

# Отображение графика
fig.show()
# Out:
# <div>                            <div id="0a3fcd98-7e7d-4bcc-b584-5d43785278f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a3fcd98-7e7d-4bcc-b584-5d43785278f6")) {                    Plotly.newPlot(                        "0a3fcd98-7e7d-4bcc-b584-5d43785278f6",                        [{"line":{"color":"blue"},"mode":"lines","name":"Current Prices","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":["27.7","31.5","39.8","53.8","62.9","78.9","92.4","109.8","142.9","159.6","175.6","192.3","183.6","190.6","188.8","181.6","234.1","286.0","353.4","375.8","417.9","460.8","496.1","575.1","595.5","653.7","640.2","584.4","514.0","551.4","565.3","512.9","510.4","560.5","629.0","678.4","746.7","865.4","1 014.8","1 071.6","1 229.0","1 451.9","1 560.0","1 637.6","1 727.5","1 723.1","1 802.6","1 939.5","2 088.6","2 137.0","2 113.2","2 374.8","2 409.7"],"type":"scatter"},{"line":{"color":"red"},"mode":"lines","name":"Constant Prices (1970)","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[27.7,29.5,31.7,34.2,33.7,36.8,38.1,38.6,41.7,43.1,44.0,45.4,45.2,44.6,43.8,44.6,46.7,50.0,53.6,56.3,62.6,64.2,65.1,67.9,68.6,70.7,74.5,73.3,70.8,70.5,70.3,70.8,72.8,75.4,78.8,83.8,91.2,98.1,101.9,108.7,116.4,124.6,131.9,141.9,151.2,159.0,168.8,175.5,181.2,186.5,184.4,188.3,196.6],"type":"scatter"}],                        {"template":{"data":{"candlestick":[{"decreasing":{"line":{"color":"#000033"}},"increasing":{"line":{"color":"#000032"}},"type":"candlestick"}],"contourcarpet":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"contourcarpet"}],"contour":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"contour"}],"heatmap":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"heatmap"}],"histogram2d":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"histogram2d"}],"icicle":[{"textfont":{"color":"white"},"type":"icicle"}],"sankey":[{"textfont":{"color":"#000036"},"type":"sankey"}],"scatter":[{"marker":{"line":{"width":0}},"type":"scatter"}],"table":[{"cells":{"fill":{"color":"#000038"},"font":{"color":"#000037"},"line":{"color":"#000039"}},"header":{"fill":{"color":"#000040"},"font":{"color":"#000036"},"line":{"color":"#000039"}},"type":"table"}],"waterfall":[{"connector":{"line":{"color":"#000036","width":2}},"decreasing":{"marker":{"color":"#000033"}},"increasing":{"marker":{"c ...
#
# var gd = document.getElementById('0a3fcd98-7e7d-4bcc-b584-5d43785278f6');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
import pandas as pd
import plotly.graph_objects as go

# Загрузка данных из CSV файла
data = pd.read_csv("asia_construction.csv")

# Создание данных для "construction per capita dollars (current prices) in World"
data['construction per capita dollars (current prices) in World'] = data['construction per capita dollars (current prices)'] * 1.1

# Создание графика
fig = go.Figure()

# Добавление кривой для construction per capita dollars (current prices)
fig.add_trace(go.Scatter(
    x=data['Year'],
    y=data['construction per capita dollars (current prices)'],
    mode='lines',
    name='Construction per Capita Dollars (Current Prices)',
    line=dict(color='blue')
))

# Добавление кривой для construction per capita dollars (current prices) in World
fig.add_trace(go.Scatter(
    x=data['Year'],
    y=data['construction per capita dollars (current prices) in World'],
    mode='lines',
    name='Construction per Capita Dollars (Current Prices) in World',
    line=dict(color='red', dash='dash')  # Использование пунктирной линии для отличия
))

# Обновление макета графика
fig.update_layout(
    title='Construction per Capita Dollars in Asia and World',
    xaxis_title='Year',
    yaxis_title='Dollars (Current Prices)',
    legend_title='Legend'
)

# Отображение графика
fig.show()
# Out:
# <div>                            <div id="f150824e-1de0-4387-98c3-4aefada98d21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f150824e-1de0-4387-98c3-4aefada98d21")) {                    Plotly.newPlot(                        "f150824e-1de0-4387-98c3-4aefada98d21",                        [{"line":{"color":"blue"},"mode":"lines","name":"Construction per Capita Dollars (Current Prices)","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[13.2,14.6,18.2,24.0,27.4,33.7,38.7,45.1,57.6,63.1,68.2,73.1,68.4,69.6,67.7,63.8,80.6,96.5,116.9,121.9,130.2,141.0,149.2,170.2,173.5,187.7,181.2,163.0,141.4,149.6,151.3,135.5,133.1,144.3,160.0,170.5,185.4,212.4,246.1,256.9,291.2,340.1,361.3,375.1,391.4,386.5,400.3,426.5,455.1,461.7,453.1,505.9,510.3],"type":"scatter"},{"line":{"color":"red","dash":"dash"},"mode":"lines","name":"Construction per Capita Dollars (Current Prices) in World","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[14.52,16.060000000000002,20.02,26.400000000000002,30.14,37.07000000000001,42.57000000000001,49.61000000000001,63.36000000000001,69.41000000000001,75.02000000000001,80.41,75.24000000000001,76.56,74.47000000000001,70.18,88.66,106.15,128.59,134.09,143.22,155.10000000000002,164.12,187.22,190.85000000000002,206.47,199.32,179.3,155.54000000000002,164.56,166.43000000000004,149.05,146.41,158.73000000000002,176.0,187.55,203.94000000000003,233.64000000000001,270.71000000000004,282.59,320.32,374.11000000000007,397.43000000000006,412.61000000000007,430.54,425.15000000000003,440.33000000000004,469.15000000000003,500.61000000000007,507.87,498.4100000000001,556.49,561.33],"type":"scatter"}],                        {"template":{"data":{"candlestick":[{"decreasing":{"line":{"color":"#000033"}},"increasing":{"line":{"color":"#000032"}},"type":"candlestick"}],"contourcarpet":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"contourcarpet"}],"contour":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"contour"}],"heatmap":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"heatmap"}],"histogram2d":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"histogram2d"}],"icicle":[{"textfont":{"color":"white"},"type":"icicle"}],"sankey":[{"textfont":{"color":"#000036"},"type":"sankey"}],"scatter":[{"marker":{"line":{"width":0}},"type":"scatter"}],"table":[{"cells":{"fill ...
#
# var gd = document.getElementById('f150824e-1de0-4387-98c3-4aefada98d21');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
import pandas as pd
import plotly.graph_objects as go

# Загрузка данных из CSV файла
data = pd.read_csv("asia_construction.csv")

# Создание графика
fig = go.Figure()

# Добавление столбцов для construction growth % (constant prices 1970)
fig.add_trace(go.Bar(
    x=data['Year'],
    y=data['construction growth % (constant prices 1970)'],
    name='Construction Growth (%) (Constant Prices 1970)',
    marker_color='blue'
))

# Обновление макета графика
fig.update_layout(
    title='Construction Growth in Asia',
    xaxis_title='Year',
    yaxis_title='Growth Percentage (%)',
    legend_title='Legend',
    yaxis=dict(range=[0, data['construction growth % (constant prices 1970)'].max() + 5]),  # Установка диапазона оси Y
    barmode='group'
)

# Отображение графика
fig.show()
# Out:
# <div>                            <div id="49803719-3eec-45bb-a60d-3b2a266a8ca4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49803719-3eec-45bb-a60d-3b2a266a8ca4")) {                    Plotly.newPlot(                        "49803719-3eec-45bb-a60d-3b2a266a8ca4",                        [{"marker":{"color":"blue"},"name":"Construction Growth (%) (Constant Prices 1970)","x":[1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[0.0,6.4,7.7,7.7,-1.3,9.0,3.6,1.2,8.1,3.5,2.0,3.2,-0.49,-1.3,-1.9,1.9,4.6,7.2,7.2,5.0,11.2,2.6,1.4,4.2,1.1,3.0,5.4,-1.6,-3.4,-0.45,-0.3,0.78,2.8,3.6,4.5,6.4,8.8,7.5,3.9,6.7,7.1,7.1,5.9,7.5,6.5,5.2,6.1,4.0,3.2,2.9,-1.2,2.1,4.4],"type":"bar"}],                        {"template":{"data":{"candlestick":[{"decreasing":{"line":{"color":"#000033"}},"increasing":{"line":{"color":"#000032"}},"type":"candlestick"}],"contourcarpet":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"contourcarpet"}],"contour":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"contour"}],"heatmap":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"heatmap"}],"histogram2d":[{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]],"type":"histogram2d"}],"icicle":[{"textfont":{"color":"white"},"type":"icicle"}],"sankey":[{"textfont":{"color":"#000036"},"type":"sankey"}],"scatter":[{"marker":{"line":{"width":0}},"type":"scatter"}],"table":[{"cells":{"fill":{"color":"#000038"},"font":{"color":"#000037"},"line":{"color":"#000039"}},"header":{"fill":{"color":"#000040"},"font":{"color":"#000036"},"line":{"color":"#000039"}},"type":"table"}],"waterfall":[{"connector":{"line":{"color":"#000036","width":2}},"decreasing":{"marker":{"color":"#000033"}},"increasing":{"marker":{"color":"#000032"}},"totals":{"marker":{"color":"#000034"}},"type":"waterfall"}]},"layout":{"coloraxis":{"colorscale":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0.8888888888888888,"#000019"],[1.0,"#000020"]]},"colorscale":{"diverging":[[0.0,"#000021"],[0.1,"#000022"],[0.2,"#000023"],[0.3,"#000024"],[0.4,"#000025"],[0.5,"#000026"],[0.6,"#000027"],[0.7,"#000028"],[0.8,"#000029"],[0.9,"#000030"],[1.0,"#000031"]],"sequential":[[0.0,"#000011"],[0.1111111111111111,"#000012"],[0.2222222222222222,"#000013"],[0.3333333333333333,"#000014"],[0.4444444444444444,"#000015"],[0.5555555555555556,"#000016"],[0.6666666666666666,"#000017"],[0.7777777777777778,"#000018"],[0. ...
#
# var gd = document.getElementById('49803719-3eec-45bb-a60d-3b2a266a8ca4');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
import pandas as pd
import plotly.express as px

# Загрузка данных из CSV файла с правильными параметрами
data = pd.read_csv("Construction ranking in Asia, 2022.csv", header=None, skiprows=3)

# Переименование столбцов для удобства
data.columns = ['место', 'регион_страна', 'млрд_долл', 'процент']

# Очистка данных
data = data[~data['место'].isin(['субрегионы', 'страны'])]

# Создание круговой диаграммы
fig = px.pie(data, values='млрд_долл', names='регион_страна', title='Share of Construction Spending in Asia by Region and Country in 2022')

# Отображение графика
fig.show()
# Out:
# <div>                            <div id="23cb08f4-94d9-402e-9911-f0a1ad6d1ab8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23cb08f4-94d9-402e-9911-f0a1ad6d1ab8")) {                    Plotly.newPlot(                        "23cb08f4-94d9-402e-9911-f0a1ad6d1ab8",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\u0440\u0435\u0433\u0438\u043e\u043d_\u0441\u0442\u0440\u0430\u043d\u0430=%{label}<br>\u043c\u043b\u0440\u0434_\u0434\u043e\u043b\u043b=%{value}<extra></extra>","labels":["\u0412\u043e\u0441\u0442\u043e\u0447\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u042e\u0436\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u042e\u0433\u043e-\u0412\u043e\u0441\u0442\u043e\u0447\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u0417\u0430\u043f\u0430\u0434\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u041a\u0438\u0442\u0430\u0439","\u0418\u043d\u0434\u0438\u044f","\u042f\u043f\u043e\u043d\u0438\u044f","\u0418\u043d\u0434\u043e\u043d\u0435\u0437\u0438\u044f","\u042e\u0436\u043d\u0430\u044f \u041a\u043e\u0440\u0435\u044f","\u0421\u0430\u0443\u0434\u043e\u0432\u0441\u043a\u0430\u044f \u0410\u0440\u0430\u0432\u0438\u044f","\u0411\u0430\u043d\u0433\u043b\u0430\u0434\u0435\u0448","\u041e\u0410\u042d","\u0424\u0438\u043b\u0438\u043f\u043f\u0438\u043d\u044b","\u0418\u0437\u0440\u0430\u0438\u043b\u044c","\u041a\u0430\u0442\u0430\u0440","\u0412\u044c\u0435\u0442\u043d\u0430\u043c","\u0413\u043e\u043d\u0433 \u041a\u043e\u043d\u0433","\u041c\u0430\u043b\u0430\u0439\u0437\u0438\u044f","\u0422\u0430\u0439\u043b\u0430\u043d\u0434","\u0421\u0438\u043d\u0433\u0430\u043f\u0443\u0440","\u041a\u0430\u0437\u0430\u0445\u0441\u0442\u0430\u043d","\u0418\u0440\u0430\u043d","\u041e\u043c\u0430\u043d","\u041f\u0430\u043a\u0438\u0441\u0442\u0430\u043d","\u0428\u0440\u0438 \u041b\u0430\u043d\u043a\u0430","\u0418\u0440\u0430\u043a","\u0423\u0437\u0431\u0435\u043a\u0438\u0441\u0442\u0430\u043d","\u0422\u0443\u0440\u043a\u043c\u0435\u043d\u0438\u0441\u0442\u0430\u043d","\u041a\u0443\u0432\u0435\u0439\u0442","\u041a\u0430\u043c\u0431\u043e\u0434\u0436\u0430","\u041c\u044c\u044f\u043d\u043c\u0430","\u0410\u0437\u0435\u0440\u0431\u0430\u0439\u0434\u0436\u0430\u043d","\u0411\u0430\u0445\u0440\u0435\u0439\u043d","\u041d\u0435\u043f\u0430\u043b","\u041c\u0430\u043a\u0430\u043e","\u0413\u0440\u0443\u0437\u0438\u044f","\u0421\u0435\u0432\u0435\u0440\u043d\u0430\u044f \u041a\u043e\u0440\u0435\u044f","\u041b\u0430\u043e\u0441","\u041a\u0438\u043f\u0440","\u0418\u043e\u0440\u0434\u0430\u043d\u0438\u044f","\u0410\u0440\u043c\u0435\u043d\u0438\u044f","\u041b\u0438\u0432\u0430\u043d","\u041f\u0430\u043b\u0435\u0441\u0442\u0438\u043d\u0430","\u0422\u0430\u0434\u0436\u0438\u043a\u0438\u0441\u0442\u0430\u043d","\u041a\u0438\u0440\u0433\u0438\u0437\u0441\u0442\u0430\u043d","\u041c\u043e\u043d\u0433\u043e\u043b\u0438\u044f","\u0419\u0435\u043c\u0435\u043d","\u041c\u0430\u043b\u044c\u0434\u0438\u0432\u044b","\u0411\u0440\u0443\u043d\u0435\u0439","\u0411\u0443\u0442\u0430\u043d","\u0421\u0438\u0440\u0438\u044f","\u0412\u043e\u0441\u0442\u043e\u0447\u043d\u044b\u0439 \u0422\u0438\u043c\u043e\u0440","\u0410\u0444\u0433\u0430\u043d\u0438\u0441\u0442\u0430\u043d"],"legendgroup":"","name":"","showlegend":true,"values":["1 603.2","326.2","232.5","224.5","23.3","1 237.7","257.9","235.0","128.8","86.8","49.8","40.3","37.5","29.6","29.2","27.3","25.3","15.0","13.8","12.5","12.2","11.9","10.2","10.0","9.0","6.1","6.0","5.0","4.8","4.4","4.4","4.0","3.8","3.5","2.0","1.7","1.7","1.6","1.4","1.4","1.3","1.3","1.1","0.95","0.83","0.81","0.57","0.56","0.38","0.32","0.23","0.18","0.15","0.14"],"type":"pie"}],                        {"templa ...
#
# var gd = document.getElementById('23cb08f4-94d9-402e-9911-f0a1ad6d1ab8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-conta

# %%
import pandas as pd
import plotly.express as px

# Загрузка данных из CSV файла
data = pd.read_csv("Construction ranking in Asia, 2022.csv", header=None, skiprows=3)

# Переименование столбцов для удобства
data.columns = ['место', 'регион_страна', 'млрд_долл', 'процент']

# Убираем подзаголовки, которые используются для обозначения разделов в CSV-файле
data = data[~data['место'].isin(['субрегионы', 'страны'])]

# Создаем карту мира с данными стран Азии
fig = px.choropleth(locations=data['регион_страна'], locationmode='country names', color=data['процент'],
                    title='Construction Spending Share in Asia by Country in 2022',
                    hover_name=data['регион_страна'], color_continuous_scale='Viridis',
                    labels={'процент': 'Share (%)'})

# Отображение карты
fig.show()
# Out:
# <div>                            <div id="1c507ea6-0a70-4a75-a2f0-c4fb4c27528b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c507ea6-0a70-4a75-a2f0-c4fb4c27528b")) {                    Plotly.newPlot(                        "1c507ea6-0a70-4a75-a2f0-c4fb4c27528b",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>locations=%{location}<br>color=%{z}<extra></extra>","hovertext":["\u0412\u043e\u0441\u0442\u043e\u0447\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u042e\u0436\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u042e\u0433\u043e-\u0412\u043e\u0441\u0442\u043e\u0447\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u0417\u0430\u043f\u0430\u0434\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u041a\u0438\u0442\u0430\u0439","\u0418\u043d\u0434\u0438\u044f","\u042f\u043f\u043e\u043d\u0438\u044f","\u0418\u043d\u0434\u043e\u043d\u0435\u0437\u0438\u044f","\u042e\u0436\u043d\u0430\u044f \u041a\u043e\u0440\u0435\u044f","\u0421\u0430\u0443\u0434\u043e\u0432\u0441\u043a\u0430\u044f \u0410\u0440\u0430\u0432\u0438\u044f","\u0411\u0430\u043d\u0433\u043b\u0430\u0434\u0435\u0448","\u041e\u0410\u042d","\u0424\u0438\u043b\u0438\u043f\u043f\u0438\u043d\u044b","\u0418\u0437\u0440\u0430\u0438\u043b\u044c","\u041a\u0430\u0442\u0430\u0440","\u0412\u044c\u0435\u0442\u043d\u0430\u043c","\u0413\u043e\u043d\u0433 \u041a\u043e\u043d\u0433","\u041c\u0430\u043b\u0430\u0439\u0437\u0438\u044f","\u0422\u0430\u0439\u043b\u0430\u043d\u0434","\u0421\u0438\u043d\u0433\u0430\u043f\u0443\u0440","\u041a\u0430\u0437\u0430\u0445\u0441\u0442\u0430\u043d","\u0418\u0440\u0430\u043d","\u041e\u043c\u0430\u043d","\u041f\u0430\u043a\u0438\u0441\u0442\u0430\u043d","\u0428\u0440\u0438 \u041b\u0430\u043d\u043a\u0430","\u0418\u0440\u0430\u043a","\u0423\u0437\u0431\u0435\u043a\u0438\u0441\u0442\u0430\u043d","\u0422\u0443\u0440\u043a\u043c\u0435\u043d\u0438\u0441\u0442\u0430\u043d","\u041a\u0443\u0432\u0435\u0439\u0442","\u041a\u0430\u043c\u0431\u043e\u0434\u0436\u0430","\u041c\u044c\u044f\u043d\u043c\u0430","\u0410\u0437\u0435\u0440\u0431\u0430\u0439\u0434\u0436\u0430\u043d","\u0411\u0430\u0445\u0440\u0435\u0439\u043d","\u041d\u0435\u043f\u0430\u043b","\u041c\u0430\u043a\u0430\u043e","\u0413\u0440\u0443\u0437\u0438\u044f","\u0421\u0435\u0432\u0435\u0440\u043d\u0430\u044f \u041a\u043e\u0440\u0435\u044f","\u041b\u0430\u043e\u0441","\u041a\u0438\u043f\u0440","\u0418\u043e\u0440\u0434\u0430\u043d\u0438\u044f","\u0410\u0440\u043c\u0435\u043d\u0438\u044f","\u041b\u0438\u0432\u0430\u043d","\u041f\u0430\u043b\u0435\u0441\u0442\u0438\u043d\u0430","\u0422\u0430\u0434\u0436\u0438\u043a\u0438\u0441\u0442\u0430\u043d","\u041a\u0438\u0440\u0433\u0438\u0437\u0441\u0442\u0430\u043d","\u041c\u043e\u043d\u0433\u043e\u043b\u0438\u044f","\u0419\u0435\u043c\u0435\u043d","\u041c\u0430\u043b\u044c\u0434\u0438\u0432\u044b","\u0411\u0440\u0443\u043d\u0435\u0439","\u0411\u0443\u0442\u0430\u043d","\u0421\u0438\u0440\u0438\u044f","\u0412\u043e\u0441\u0442\u043e\u0447\u043d\u044b\u0439 \u0422\u0438\u043c\u043e\u0440","\u0410\u0444\u0433\u0430\u043d\u0438\u0441\u0442\u0430\u043d"],"locationmode":"country names","locations":["\u0412\u043e\u0441\u0442\u043e\u0447\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u042e\u0436\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u042e\u0433\u043e-\u0412\u043e\u0441\u0442\u043e\u0447\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u0417\u0430\u043f\u0430\u0434\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u0426\u0435\u043d\u0442\u0440\u0430\u043b\u044c\u043d\u0430\u044f \u0410\u0437\u0438\u044f","\u041a\u0438\u0442\u0430\u0439","\u0418\u043d\u0434\u0438\u044f","\u042f\u043f\u043e\u043d\u0438\u04 ...
